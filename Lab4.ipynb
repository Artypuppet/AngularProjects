# %% [markdown]
# <a href="https://colab.research.google.com/github/Artypuppet/AngularProjects/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn import tree
from sklearn import preprocessing
import graphviz



dataset = np.array([
['sunny', 85, 85, 0, 'Don\'t Play'],
['sunny', 80, 90, 1, 'Don\'t Play'],
['overcast', 83, 78, 0, 'Play'],
['rain', 70, 96, 0, 'Play'],
['rain', 68, 80, 0, 'Play'],
['rain', 65, 70, 1, 'Don\'t Play'],
['overcast', 64, 65, 1, 'Play'],
['sunny', 72, 95, 0, 'Don\'t Play'],
['sunny', 69, 70, 0, 'Play'],
['rain', 75, 80, 0, 'Play'],
['sunny', 75, 70, 1, 'Play'],
['overcast', 72, 90,1, 'Play'],
['overcast', 81, 75, 0, 'Play'],
['rain', 71, 80, 1, 'Don\'t Play'],
])

X = dataset[:, 0:4]

y = dataset[:, 4]


le = preprocessing.LabelEncoder()
X[:, 0] = le.fit_transform(X[:, 0])
y = le.fit_transform(y)

dtc = tree.DecisionTreeClassifier(criterion="entropy")

dtc.fit(X,y)

tree.plot_tree(dtc)

dot_data = tree.export_graphviz(dtc, out_file=None,
feature_names=['Outlook', 'Temperature', 'Humidity', 'Windy'],
class_names=['Don\'t Play', 'Play'],
filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph.render("mytree")
# Out:
# 'mytree.pdf'
